# %%
import numpy as np
import random
import pandas as pd
import scipy.io
import matplotlib.pyplot as plt
from qiskit.quantum_info import DensityMatrix, random_density_matrix
from qiskit.quantum_info.operators import Operator
import tensorflow as tf

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from scipy.linalg import sqrtm
from scipy.optimize import minimize

import torch
#tensorflow imports
from tensorflow import keras
from keras import layers, losses, Model
import logging
tf.get_logger().setLevel(logging.ERROR)

# %%
data_10 = np.load('../datasets/new_shot_levels/2q_10_.npz')
data_20 = np.load('../datasets/new_shot_levels/2q_20_.npz')
data_50 = np.load('../datasets/new_shot_levels/2q_50_.npz')
data_100 = np.load('../datasets/new_shot_levels/2q_1h_.npz')
data_1k = np.load('../datasets/new_shot_levels/2q_1k_.npz')
data_5k = np.load('../datasets/new_shot_levels/2q_5k_.npz')
data_10k = np.load('../datasets/new_shot_levels/2q_10k_.npz')

X_10 = data_10['counts']; y_10 = data_10['states']
X_20 = data_20['counts']; y_20 = data_20['states']
X_50 = data_50['counts']; y_50 = data_50['states']
X_100 = data_100['counts']; y_100 = data_100['states']
X_1k = data_1k['counts']; y_1k = data_1k['states']
X_5k = data_5k['counts']; y_5k = data_5k['states']
X_10k = data_10k['counts']; y_10k = data_10k['states']

# %% [markdown]
# # MLE Fidelity curves

# %%
# compute Fidelity
def fidelity(rho1, rho2):
    sqrt_rho1 = sqrtm(rho1)
    F = np.trace(sqrtm(sqrt_rho1 @ rho2 @ sqrt_rho1))
    return np.real(F)**2

# Map the cholesky parameterised vector to a PSD trace 1 density matrix
def params_to_rho(params):
    # params: length 16
    L = np.zeros((4,4), dtype=complex)
    idx = 0
    # diagonal entries (real, positive)
    for i in range(4):
        L[i, i] = params[idx]
        idx += 1
    # lower-triangular off-diagonals (real + imag)
    for i in range(1, 4):
        for j in range(i):
            re = params[idx]; im = params[idx+1]
            L[i, j] = re + 1j * im
            idx += 2
    rho = L @ L.conj().T
    return rho / np.trace(rho)


def build_single_qubit_Us():
    X_cols = [np.array([1, 1])/np.sqrt(2),
              np.array([1,-1])/np.sqrt(2)]
    Y_cols = [np.array([1, 1j])/np.sqrt(2),
              np.array([1,-1j])/np.sqrt(2)] 
    Z_cols = [np.array([1,0]), np.array([0,1])]
    return {'X': np.column_stack(X_cols),
            'Y': np.column_stack(Y_cols),
            'Z': np.column_stack(Z_cols)}

def build_povm():
    proj = []
    for m in range(4):
        P = np.zeros((4,4), dtype=complex)
        P[m, m] = 1.0
        proj.append(P)

    Us = build_single_qubit_Us()
    settings = []
    for b1 in ['X','Y','Z']:
        for b2 in ['X','Y','Z']:
            settings.append(np.kron(Us[b1], Us[b2]))

    E = []
    for U in settings:
        U_dag = U.conj().T
        for P in proj:
            E.append(U @ P @ U_dag)
    return E

E_GLOBAL = build_povm()

def neg_log_likelihood(params, count):
    rho = params_to_rho(params)
    rho = 0.5*(rho + rho.conj().T)
    probs = np.array([np.trace(E @ rho).real for E in E_GLOBAL])
    probs = np.clip(probs, 0.0, None)
    s = probs.sum()
    if s <= 0: probs[:] = 1.0/len(probs)
    else: probs /= s
    return -np.sum(count * np.log(np.clip(probs, 1e-12, 1.0)))


def MLE_Avg_fidelity(data, X, y):
    shots = data['shots_per_basis']
    counts = (X * shots).astype(int)        # freq counts    

    N = X.shape[0]
    #initialise the estimator
    rho_est = np.zeros((N, 4, 4), dtype=complex)

    for i in range(N):
    
        # initial guess: uniform identity
        init = np.zeros(16)
        init[:4] = np.sqrt(1/4)
    
        res = minimize(
            neg_log_likelihood, init, args=(counts[i],),
            method='L-BFGS-B',
            options={'maxiter': 500}
        )
        #reconstruct the density matrix from cholesky decomp
        rho_est[i] = params_to_rho(res.x)

    fidelities = np.array([fidelity(rho_est[i], y[i]) for i in range(N)])

    mean_fidelity = np.mean(fidelities)
    std_fidelity  = np.std(fidelities)
    return (mean_fidelity, std_fidelity)

# %% [markdown]
# # NN functions

# %%
def alpha_to_rho(alpha):
    """Convert batch of alpha vectors to density matrices using Cholesky."""
    N = alpha.shape[0]
    rho = np.zeros((N, 4, 4), dtype=np.complex64)
    for i in range(N):
        a = alpha[i]
        L = np.zeros((4, 4), dtype=np.complex64)
        idx = 0
        for j in range(4):
            L[j, j] = a[idx]
            idx += 1
        for j in range(1, 4):
            for k in range(j):
                re = a[idx]
                im = a[idx + 1]
                L[j, k] = re + 1j * im
                idx += 2
        rho_i = L @ L.conj().T
        rho[i] = rho_i / np.trace(rho_i)
    return rho

def reconstruct_true_rho(y):
    """Convert vectorized real+imag back to complex 4x4 matrices."""
    N = y.shape[0]
    real = y[:, :16].reshape(N, 4, 4)
    imag = y[:, 16:].reshape(N, 4, 4)
    return real + 1j * imag


def rho_to_alpha(rho):
    """
    Convert a (d x d) density matrix rho into its "Cholesky parameters" alpha.
    """
    L = np.linalg.cholesky(rho + 1e-14 * np.eye(rho.shape[0]))
    d = rho.shape[0]
    alpha = []
    # diagonal (real, >0)
    for i in range(d):
        alpha.append(np.real(L[i, i]))
    # strictly lower triangle (real + imag)
    for i in range(1, d):
        for j in range(i):
            alpha.append(np.real(L[i, j]))
            alpha.append(np.imag(L[i, j]))
    return np.array(alpha, dtype=np.float32)

def fidelity(rho1, rho2):
    A = sqrtm(rho1)
    return np.real(np.trace(sqrtm(A @ rho2 @ A)))**2


def tf_sqrtm_psd(A):
    """
    Compute principal sqrt of Hermitian PSD A (batch,d,d) via eigendecomposition.
    """
    
    eigvals, eigvecs = tf.linalg.eigh(A)

    eigvals = tf.math.real(eigvals)
    eigvals = tf.clip_by_value(eigvals, 0.0, tf.reduce_max(eigvals))
    sqrtvals = tf.sqrt(eigvals)
    D = tf.cast(tf.linalg.diag(sqrtvals), tf.complex64)
    
    return eigvecs @ D @ tf.linalg.adjoint(eigvecs)

def tf_alpha_to_rho(alpha, d):
    """
    Map real alpha (batch, N_alpha) -> complex density matrices (batch, d, d).
    Enforces positivity via a softplus on the Cholesky diag.
    """
    batch = tf.shape(alpha)[0]
    # split diag vs off-diag
    raw_diag = alpha[:, :d] 
    off_vals  = alpha[:, d:] 

    # start zero L
    L = tf.zeros((batch, d, d), tf.complex64)

    diag_pos = tf.nn.softplus(raw_diag) + 1e-6 
    diag_c   = tf.cast(diag_pos, tf.complex64)
    L = tf.linalg.set_diag(L, diag_c)

    idx = 0
    for i in range(1, d):
        for j in range(i):
            re = off_vals[:, idx]
            im = off_vals[:, idx+1]
            idx += 2
            cij = (tf.cast(re, tf.complex64)
                   + 1j * tf.cast(im, tf.complex64))
            cij = tf.reshape(cij, (batch, 1, 1))

            # mask with a one-hot at (i,j)
            flat = tf.one_hot(i*d + j, d*d, dtype=tf.complex64)
            mask = tf.reshape(flat, (d, d))[None, :, :]

            L = L + cij * mask

    rho = L @ tf.linalg.adjoint(L)  
    tr  = tf.linalg.trace(rho)
    return rho / tr[:, None, None]

def make_fidelity_loss(d):
    def fidelity_loss(alpha_true, alpha_pred):
        rho_t = tf_alpha_to_rho(alpha_true, d)
        rho_p = tf_alpha_to_rho(alpha_pred, d)

        # tiny regularizer to guard numeric issues
        I = tf.eye(d, dtype=tf.complex64)[None, :, :]
        rho_t = rho_t + 1e-8 * I
        rho_p = rho_p + 1e-8 * I

        sqrt_t = tf_sqrtm_psd(rho_t)
        inter  = sqrt_t @ (rho_p @ sqrt_t)
        s_mat  = tf_sqrtm_psd(inter)

        tr_s = tf.linalg.trace(s_mat)
        F = tf.abs(tr_s)**2
        return tf.reduce_mean(1.0 - F)
    return fidelity_loss

def make_hybrid_loss(d, lam=0.8):
    """
    Hybrid loss = lam * MSE + (1 - lam) * (1 - fidelity).
    """
    fid_loss_fn = make_fidelity_loss(d)

    def hybrid_loss(alpha_true, alpha_pred):
        # MSE on the Cholesky parameters
        mse = tf.reduce_mean(tf.square(alpha_true - alpha_pred))

        # fidelity loss already = mean(1 - F)
        phys = fid_loss_fn(alpha_true, alpha_pred)

        return lam * mse + (1.0 - lam) * phys

    return hybrid_loss

def alpha_to_rho_batch(alpha):
    """Convert batch of alpha vectors to density matrices using Cholesky."""
    N = alpha.shape[0]
    rho = np.zeros((N, 4, 4), dtype=np.complex64)
    for i in range(N):
        a = alpha[i]
        L = np.zeros((4, 4), dtype=np.complex64)
        idx = 0
        for j in range(4):
            L[j, j] = a[idx]
            idx += 1
        for j in range(1, 4):
            for k in range(j):
                re = a[idx]
                im = a[idx + 1]
                L[j, k] = re + 1j * im
                idx += 2
        rho_i = L @ L.conj().T
        rho[i] = rho_i / np.trace(rho_i)
    return rho

def train_NN_fidelity(X, y, lam=0.8):
    X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, random_state=2)

    alphas = np.stack([rho_to_alpha(y[i]) for i in range(len(y))], axis=0)
    d = y_train.shape[1]

    alphas_train = np.stack([rho_to_alpha(rho) for rho in y_train], axis=0)
    N_alpha = alphas_train.shape[1]

    model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(X_train.shape[1],)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(128, activation="relu"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(128, activation="relu"),
    tf.keras.layers.Dense(N_alpha),
    ])

    model.compile(
        optimizer=tf.keras.optimizers.Adam(1e-3),
        loss=make_hybrid_loss(d, lam=lam),
    )

    # fit
    history = model.fit(
        X_train, alphas_train,
        validation_split=0.3,
        epochs=50,
        batch_size=64,
    )

    alpha_pred = model.predict(X_test)      
    rho_pred = alpha_to_rho_batch(alpha_pred)  

    # Compute fidelities
    fidelities = np.array([
        fidelity(rho_pred[i], y_test[i])
        for i in range(len(rho_pred))
    ])

    # Summary
    mean_fid = np.mean(fidelities)
    std_fid = np.std(fidelities)
    return(mean_fid, std_fid)

def train_vanilla_NN_fidelity(X, y):
    X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, random_state=2)

    alphas = np.stack([rho_to_alpha(y[i]) for i in range(len(y))], axis=0)
    d = y_train.shape[1]

    alphas_train = np.stack([rho_to_alpha(rho) for rho in y_train], axis=0)
    N_alpha = alphas_train.shape[1]

    model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(X_train.shape[1],)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(128, activation="relu"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(128, activation="relu"),
    tf.keras.layers.Dense(N_alpha),
    ])

    model.compile(
        optimizer=tf.keras.optimizers.Adam(1e-3),
        loss="mse"
    )

    # fit
    history = model.fit(
        X_train, alphas_train,
        validation_split=0.2,
        epochs=50,
        batch_size=64,
    )

    alpha_pred = model.predict(X_test)      
    rho_pred = alpha_to_rho_batch(alpha_pred)  

    # Compute fidelities
    fidelities = np.array([
        fidelity(rho_pred[i], y_test[i])
        for i in range(len(rho_pred))
    ])

    # Summary
    mean_fid = np.mean(fidelities)
    std_fid = np.std(fidelities)
    return(mean_fid, std_fid)

# %%
fid_NN_10, std_NN_10 = train_vanilla_NN_fidelity(X_10, y_10)
# Out:
# Epoch 1/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 2s 843us/step - loss: 0.1815 - val_loss: 0.0244
# Epoch 2/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 1s 746us/step - loss: 0.0304 - val_loss: 0.0204
# Epoch 3/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 1s 743us/step - loss: 0.0249 - val_loss: 0.0194
# Epoch 4/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 1s 904us/step - loss: 0.0231 - val_loss: 0.0184
# Epoch 5/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 1s 817us/step - loss: 0.0225 - val_loss: 0.0180
# Epoch 6/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 1s 781us/step - loss: 0.0221 - val_loss: 0.0179
# Epoch 7/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 1s 772us/step - loss: 0.0217 - val_loss: 0.0175
# Epoch 8/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 1s 776us/step - loss: 0.0215 - val_loss: 0.0171
# Epoch 9/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 1s 811us/step - loss: 0.0213 - val_loss: 0.0175
# Epoch 10/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 1s 743us/step - loss: 0.0213 - val_loss: 0.0169
# Epoch 11/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 1s 821us/step - loss: 0.0209 - val_loss: 0.0169
# Epoch 12/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 1s 780us/step - loss: 0.0210 - val_loss: 0.0171
# Epoch 13/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 1s 798us/step - loss: 0.0208 - val_loss: 0.0170
# Epoch 14/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 1s 826us/step - loss: 0.0208 - val_loss: 0.0169
# Epoch 15/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 1s 751us/step - loss: 0.0207 - val_loss: 0.0167
# Epoch 16/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 1s 788us/step - loss: 0.0206 - val_loss: 0.0167
# Epoch 17/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 1s 825us/step - loss: 0.0207 - val_loss: 0.0166
# Epoch 18/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 1s 766us/step - loss: 0.0206 - val_loss: 0.0169
# Epoch 19/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 1s 798us/step - loss: 0.0206 - val_loss: 0.0165
# Epoch 20/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 1s 821us/step - loss: 0.0204 - val_loss: 0.0164
# Epoch 21/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 1s 795us/step - loss: 0.0204 - val_loss: 0.0165
# Epoch 22/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 1s 849us/step - loss: 0.0205 - val_loss: 0.0168
# Epoch 23/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 1s 751us/step - loss: 0.0203 - val_loss: 0.0166
# Epoch 24/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 1s 775us/step - loss: 0.0203 - val_loss: 0.0166
# Epoch 25/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 1s 748us/step - loss: 0.0203 - val_loss: 0.0167
# Epoch 26/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 1s 760us/step - loss: 0.0202 - val_loss: 0.0167
# Epoch 27/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 1s 872us/step - loss: 0.0203 - val_loss: 0.0164
# Epoch 28/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 1s 829us/step - loss: 0.0202 - val_loss: 0.0166
# Epoch 29/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 1s 894us/step - loss: 0.0201 - val_loss: 0.0166
# Epoch 30/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 1s 750us/step - loss: 0.0202 - val_loss: 0.0166
# Epoch 31/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 1s 761us/step - loss: 0.0199 - val_loss: 0.0170
# Epoch 32/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 1s 744us/step - loss: 0.0201 - val_loss: 0.0168
# Epoch 33/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 1s 762us/step - loss: 0.0201 - val_loss: 0.0165
# Epoch 34/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 1s 767us/step - loss: 0.0202 - val_loss: 0.0167
# Epoch 35/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 1s 757us/step - loss: 0.0201 - val_loss: 0.0167
# Epoch 36/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 1s 804us/step - loss: 0.0199 - val_loss: 0.0168
# Epoch 37/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 1s 749us/step - loss: 0.0202 - val_loss: 0.0165
# Epoch 38/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 1s 814us/step - loss: 0.0200 - val_loss: 0.0165
# Epoch 39/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 1s 803us/step - loss: 0.0199 - val_loss: 0.0167
# Epoch 40/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 1s 798us/step - loss: 0.0199 - val_loss: 0.0163
# Epoch 41/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 1s 864us/step - loss: 0.0200 - val_loss: 0.0170
# Epoch 42/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 1s 735us/step - loss: 0.0201 - val_loss: 0.0168
# Epoch 43/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 1s 777us/step - loss: 0.0199 - val_loss: 0.0167
# Epoch 44/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 1s 799us/step - loss: 0.0200 - val_loss: 0.0168
# Epoch 45/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 1s 738us/step - loss: 0.0198 - val_loss: 0.0166
# Epoch 46/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 1s 820us/step - loss: 0.0200 - val_loss: 0.0167
# Epoch 47/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 1s 757us/step - loss: 0.0199 - val_loss: 0.0166
# Epoch 48/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 1s 750us/step - loss: 0.0199 - val_loss: 0.0167
# Epoch 49/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 1s 751us/step - loss: 0.0199 - val_loss: 0.0166
# Epoch 50/50
# 875/875 ━━━━━━━━━━━━━━━━━━━━ 1s 751us/step - loss: 0.0200 - val_loss: 0.0167
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 312us/step

# %%
fid_NN_10
# Out:
# 0.8502760406591003

# %%
fid_NN_20, std_NN_20 = train_NN_fidelity(X_20, y_20)
fid_NN_50, std_NN_50 = train_NN_fidelity(X_50, y_50)
fid_NN_100, std_NN_100 = train_NN_fidelity(X_100, y_100)
fid_NN_5k, std_NN_5k = train_NN_fidelity(X_5k, y_5k)
fid_NN_10k, std_NN_10k = train_NN_fidelity(X_10k, y_10k)
# Out:
# Epoch 1/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.1745 - val_loss: 0.0233
# Epoch 2/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0310 - val_loss: 0.0189
# Epoch 3/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0250 - val_loss: 0.0171
# Epoch 4/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0232 - val_loss: 0.0164
# Epoch 5/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0221 - val_loss: 0.0156
# Epoch 6/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0215 - val_loss: 0.0155
# Epoch 7/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0210 - val_loss: 0.0150
# Epoch 8/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0209 - val_loss: 0.0150
# Epoch 9/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0206 - val_loss: 0.0147
# Epoch 10/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0203 - val_loss: 0.0144
# Epoch 11/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0203 - val_loss: 0.0144
# Epoch 12/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0202 - val_loss: 0.0143
# Epoch 13/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0199 - val_loss: 0.0142
# Epoch 14/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0198 - val_loss: 0.0140
# Epoch 15/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0198 - val_loss: 0.0139
# Epoch 16/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0196 - val_loss: 0.0142
# Epoch 17/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0196 - val_loss: 0.0143
# Epoch 18/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0195 - val_loss: 0.0140
# Epoch 19/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0196 - val_loss: 0.0141
# Epoch 20/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0197 - val_loss: 0.0138
# Epoch 21/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0195 - val_loss: 0.0140
# Epoch 22/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0195 - val_loss: 0.0137
# Epoch 23/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0193 - val_loss: 0.0139
# Epoch 24/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0192 - val_loss: 0.0140
# Epoch 25/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0192 - val_loss: 0.0141
# Epoch 26/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0191 - val_loss: 0.0137
# Epoch 27/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0190 - val_loss: 0.0141
# Epoch 28/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0192 - val_loss: 0.0137
# Epoch 29/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0189 - val_loss: 0.0138
# Epoch 30/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0189 - val_loss: 0.0138
# Epoch 31/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0189 - val_loss: 0.0141
# Epoch 32/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0190 - val_loss: 0.0139
# Epoch 33/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0190 - val_loss: 0.0142
# Epoch 34/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0189 - val_loss: 0.0138
# Epoch 35/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0189 - val_loss: 0.0138
# Epoch 36/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0189 - val_loss: 0.0140
# Epoch 37/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0188 - val_loss: 0.0141
# Epoch 38/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0188 - val_loss: 0.0139
# Epoch 39/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0189 - val_loss: 0.0137
# Epoch 40/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0188 - val_loss: 0.0137
# Epoch 41/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0190 - val_loss: 0.0138
# Epoch 42/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0189 - val_loss: 0.0135
# Epoch 43/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0188 - val_loss: 0.0139
# Epoch 44/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0188 - val_loss: 0.0138
# Epoch 45/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0189 - val_loss: 0.0141
# Epoch 46/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0188 - val_loss: 0.0134
# Epoch 47/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0188 - val_loss: 0.0135
# Epoch 48/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0187 - val_loss: 0.0134
# Epoch 49/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0188 - val_loss: 0.0138
# Epoch 50/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0187 - val_loss: 0.0139
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 292us/step
# Epoch 1/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.1541 - val_loss: 0.0178
# Epoch 2/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0260 - val_loss: 0.0138
# Epoch 3/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0203 - val_loss: 0.0121
# Epoch 4/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0185 - val_loss: 0.0113
# Epoch 5/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0174 - val_loss: 0.0104
# Epoch 6/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0169 - val_loss: 0.0101
# Epoch 7/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0166 - val_loss: 0.0099
# Epoch 8/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0161 - val_loss: 0.0097
# Epoch 9/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0158 - val_loss: 0.0096
# Epoch 10/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0156 - val_loss: 0.0095
# Epoch 11/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0154 - val_loss: 0.0094
# Epoch 12/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0154 - val_loss: 0.0094
# Epoch 13/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0153 - val_loss: 0.0093
# Epoch 14/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0151 - val_loss: 0.0092
# Epoch 15/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0151 - val_loss: 0.0091
# Epoch 16/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0149 - val_loss: 0.0091
# Epoch 17/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0147 - val_loss: 0.0090
# Epoch 18/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.0149 - val_loss: 0.0090
# Epoch 19/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0147 - val_loss: 0.0090
# Epoch 20/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0146 - val_loss: 0.0095
# Epoch 21/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0147 - val_loss: 0.0088
# Epoch 22/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0145 - val_loss: 0.0087
# Epoch 23/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0145 - val_loss: 0.0090
# Epoch 24/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0144 - val_loss: 0.0090
# Epoch 25/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0145 - val_loss: 0.0089
# Epoch 26/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0145 - val_loss: 0.0087
# Epoch 27/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0144 - val_loss: 0.0089
# Epoch 28/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0144 - val_loss: 0.0088
# Epoch 29/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0141 - val_loss: 0.0089
# Epoch 30/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0141 - val_loss: 0.0089
# Epoch 31/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0142 - val_loss: 0.0087
# Epoch 32/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0142 - val_loss: 0.0086
# Epoch 33/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0141 - val_loss: 0.0085
# Epoch 34/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0140 - val_loss: 0.0088
# Epoch 35/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0142 - val_loss: 0.0091
# Epoch 36/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0140 - val_loss: 0.0087
# Epoch 37/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0141 - val_loss: 0.0087
# Epoch 38/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0142 - val_loss: 0.0088
# Epoch 39/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0141 - val_loss: 0.0087
# Epoch 40/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0140 - val_loss: 0.0084
# Epoch 41/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0140 - val_loss: 0.0084
# Epoch 42/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0140 - val_loss: 0.0086
# Epoch 43/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0140 - val_loss: 0.0086
# Epoch 44/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0141 - val_loss: 0.0087
# Epoch 45/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0139 - val_loss: 0.0088
# Epoch 46/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0139 - val_loss: 0.0087
# Epoch 47/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0139 - val_loss: 0.0087
# Epoch 48/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0139 - val_loss: 0.0088
# Epoch 49/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0139 - val_loss: 0.0088
# Epoch 50/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0137 - val_loss: 0.0087
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 292us/step
# Epoch 1/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.1715 - val_loss: 0.0163
# Epoch 2/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0256 - val_loss: 0.0120
# Epoch 3/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0189 - val_loss: 0.0103
# Epoch 4/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0169 - val_loss: 0.0097
# Epoch 5/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0159 - val_loss: 0.0091
# Epoch 6/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0151 - val_loss: 0.0083
# Epoch 7/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0146 - val_loss: 0.0080
# Epoch 8/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0141 - val_loss: 0.0077
# Epoch 9/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0141 - val_loss: 0.0079
# Epoch 10/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0137 - val_loss: 0.0073
# Epoch 11/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0134 - val_loss: 0.0071
# Epoch 12/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0134 - val_loss: 0.0071
# Epoch 13/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0133 - val_loss: 0.0068
# Epoch 14/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0130 - val_loss: 0.0069
# Epoch 15/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0131 - val_loss: 0.0070
# Epoch 16/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0128 - val_loss: 0.0071
# Epoch 17/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0128 - val_loss: 0.0068
# Epoch 18/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0127 - val_loss: 0.0067
# Epoch 19/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0126 - val_loss: 0.0068
# Epoch 20/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0127 - val_loss: 0.0067
# Epoch 21/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0127 - val_loss: 0.0068
# Epoch 22/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0125 - val_loss: 0.0066
# Epoch 23/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0125 - val_loss: 0.0068
# Epoch 24/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0125 - val_loss: 0.0070
# Epoch 25/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0124 - val_loss: 0.0069
# Epoch 26/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0123 - val_loss: 0.0069
# Epoch 27/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0123 - val_loss: 0.0067
# Epoch 28/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0123 - val_loss: 0.0067
# Epoch 29/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0122 - val_loss: 0.0065
# Epoch 30/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0122 - val_loss: 0.0065
# Epoch 31/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0121 - val_loss: 0.0065
# Epoch 32/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0122 - val_loss: 0.0065
# Epoch 33/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0122 - val_loss: 0.0065
# Epoch 34/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0121 - val_loss: 0.0066
# Epoch 35/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0121 - val_loss: 0.0066
# Epoch 36/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0122 - val_loss: 0.0068
# Epoch 37/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0120 - val_loss: 0.0065
# Epoch 38/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0121 - val_loss: 0.0063
# Epoch 39/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0121 - val_loss: 0.0065
# Epoch 40/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0121 - val_loss: 0.0067
# Epoch 41/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0120 - val_loss: 0.0067
# Epoch 42/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0120 - val_loss: 0.0065
# Epoch 43/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0120 - val_loss: 0.0066
# Epoch 44/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0120 - val_loss: 0.0067
# Epoch 45/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0122 - val_loss: 0.0064
# Epoch 46/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0119 - val_loss: 0.0066
# Epoch 47/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0120 - val_loss: 0.0067
# Epoch 48/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0119 - val_loss: 0.0063
# Epoch 49/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0120 - val_loss: 0.0065
# Epoch 50/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0119 - val_loss: 0.0066
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 333us/step
# Epoch 1/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.1745 - val_loss: 0.0289
# Epoch 2/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0360 - val_loss: 0.0250
# Epoch 3/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0304 - val_loss: 0.0233
# Epoch 4/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0285 - val_loss: 0.0229
# Epoch 5/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0278 - val_loss: 0.0221
# Epoch 6/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0271 - val_loss: 0.0218
# Epoch 7/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0269 - val_loss: 0.0216
# Epoch 8/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0266 - val_loss: 0.0212
# Epoch 9/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0265 - val_loss: 0.0211
# Epoch 10/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0263 - val_loss: 0.0206
# Epoch 11/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0261 - val_loss: 0.0207
# Epoch 12/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0257 - val_loss: 0.0204
# Epoch 13/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0260 - val_loss: 0.0206
# Epoch 14/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0258 - val_loss: 0.0206
# Epoch 15/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0257 - val_loss: 0.0206
# Epoch 16/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0255 - val_loss: 0.0204
# Epoch 17/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0256 - val_loss: 0.0203
# Epoch 18/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0255 - val_loss: 0.0207
# Epoch 19/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0255 - val_loss: 0.0202
# Epoch 20/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0251 - val_loss: 0.0203
# Epoch 21/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0252 - val_loss: 0.0203
# Epoch 22/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0251 - val_loss: 0.0206
# Epoch 23/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0252 - val_loss: 0.0202
# Epoch 24/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0251 - val_loss: 0.0204
# Epoch 25/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0250 - val_loss: 0.0204
# Epoch 26/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0250 - val_loss: 0.0201
# Epoch 27/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0250 - val_loss: 0.0203
# Epoch 28/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0251 - val_loss: 0.0204
# Epoch 29/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0250 - val_loss: 0.0201
# Epoch 30/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0251 - val_loss: 0.0202
# Epoch 31/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0249 - val_loss: 0.0203
# Epoch 32/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0247 - val_loss: 0.0202
# Epoch 33/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0249 - val_loss: 0.0199
# Epoch 34/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0248 - val_loss: 0.0199
# Epoch 35/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0248 - val_loss: 0.0200
# Epoch 36/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0249 - val_loss: 0.0204
# Epoch 37/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0247 - val_loss: 0.0203
# Epoch 38/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0246 - val_loss: 0.0198
# Epoch 39/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0248 - val_loss: 0.0200
# Epoch 40/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0248 - val_loss: 0.0201
# Epoch 41/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0246 - val_loss: 0.0198
# Epoch 42/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0247 - val_loss: 0.0200
# Epoch 43/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0247 - val_loss: 0.0200
# Epoch 44/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0247 - val_loss: 0.0204
# Epoch 45/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0247 - val_loss: 0.0197
# Epoch 46/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0246 - val_loss: 0.0203
# Epoch 47/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0246 - val_loss: 0.0204
# Epoch 48/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0245 - val_loss: 0.0198
# Epoch 49/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0247 - val_loss: 0.0199
# Epoch 50/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0245 - val_loss: 0.0198
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 376us/step
# Epoch 1/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.1642 - val_loss: 0.0136
# Epoch 2/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0235 - val_loss: 0.0093
# Epoch 3/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0169 - val_loss: 0.0078
# Epoch 4/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0146 - val_loss: 0.0068
# Epoch 5/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0134 - val_loss: 0.0064
# Epoch 6/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0128 - val_loss: 0.0056
# Epoch 7/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0122 - val_loss: 0.0051
# Epoch 8/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0120 - val_loss: 0.0052
# Epoch 9/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0116 - val_loss: 0.0047
# Epoch 10/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0113 - val_loss: 0.0046
# Epoch 11/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0112 - val_loss: 0.0044
# Epoch 12/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0110 - val_loss: 0.0046
# Epoch 13/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0109 - val_loss: 0.0045
# Epoch 14/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0108 - val_loss: 0.0047
# Epoch 15/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0106 - val_loss: 0.0045
# Epoch 16/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0106 - val_loss: 0.0043
# Epoch 17/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0104 - val_loss: 0.0045
# Epoch 18/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0103 - val_loss: 0.0042
# Epoch 19/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0102 - val_loss: 0.0042
# Epoch 20/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0102 - val_loss: 0.0044
# Epoch 21/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0102 - val_loss: 0.0042
# Epoch 22/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0101 - val_loss: 0.0041
# Epoch 23/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0101 - val_loss: 0.0043
# Epoch 24/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0100 - val_loss: 0.0043
# Epoch 25/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0100 - val_loss: 0.0044
# Epoch 26/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0098 - val_loss: 0.0043
# Epoch 27/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0099 - val_loss: 0.0044
# Epoch 28/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0098 - val_loss: 0.0042
# Epoch 29/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0098 - val_loss: 0.0044
# Epoch 30/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0097 - val_loss: 0.0043
# Epoch 31/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0097 - val_loss: 0.0044
# Epoch 32/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0096 - val_loss: 0.0043
# Epoch 33/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0097 - val_loss: 0.0041
# Epoch 34/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0097 - val_loss: 0.0041
# Epoch 35/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0096 - val_loss: 0.0042
# Epoch 36/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0095 - val_loss: 0.0043
# Epoch 37/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0096 - val_loss: 0.0040
# Epoch 38/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0095 - val_loss: 0.0041
# Epoch 39/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0042
# Epoch 40/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0043
# Epoch 41/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0041
# Epoch 42/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0042
# Epoch 43/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0041
# Epoch 44/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0094 - val_loss: 0.0042
# Epoch 45/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0043
# Epoch 46/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0094 - val_loss: 0.0039
# Epoch 47/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0093 - val_loss: 0.0041
# Epoch 48/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0041
# Epoch 49/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0044
# Epoch 50/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0093 - val_loss: 0.0045
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 297us/step
# Epoch 1/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.1691 - val_loss: 0.0134
# Epoch 2/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0241 - val_loss: 0.0090
# Epoch 3/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0172 - val_loss: 0.0076
# Epoch 4/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0147 - val_loss: 0.0067
# Epoch 5/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0135 - val_loss: 0.0063
# Epoch 6/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0128 - val_loss: 0.0056
# Epoch 7/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0123 - val_loss: 0.0051
# Epoch 8/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0119 - val_loss: 0.0051
# Epoch 9/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0117 - val_loss: 0.0049
# Epoch 10/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0115 - val_loss: 0.0046
# Epoch 11/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0112 - val_loss: 0.0047
# Epoch 12/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0109 - val_loss: 0.0047
# Epoch 13/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0108 - val_loss: 0.0046
# Epoch 14/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0107 - val_loss: 0.0041
# Epoch 15/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0107 - val_loss: 0.0042
# Epoch 16/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0107 - val_loss: 0.0040
# Epoch 17/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0104 - val_loss: 0.0041
# Epoch 18/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0103 - val_loss: 0.0042
# Epoch 19/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0102 - val_loss: 0.0043
# Epoch 20/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0102 - val_loss: 0.0043
# Epoch 21/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0102 - val_loss: 0.0041
# Epoch 22/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0101 - val_loss: 0.0043
# Epoch 23/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0100 - val_loss: 0.0042
# Epoch 24/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0100 - val_loss: 0.0043
# Epoch 25/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0100 - val_loss: 0.0040
# Epoch 26/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0098 - val_loss: 0.0044
# Epoch 27/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0098 - val_loss: 0.0042
# Epoch 28/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0098 - val_loss: 0.0044
# Epoch 29/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0099 - val_loss: 0.0044
# Epoch 30/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0099 - val_loss: 0.0041
# Epoch 31/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0096 - val_loss: 0.0041
# Epoch 32/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0097 - val_loss: 0.0042
# Epoch 33/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0096 - val_loss: 0.0042
# Epoch 34/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0097 - val_loss: 0.0043
# Epoch 35/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0095 - val_loss: 0.0042
# Epoch 36/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0095 - val_loss: 0.0042
# Epoch 37/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0096 - val_loss: 0.0041
# Epoch 38/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0094 - val_loss: 0.0042
# Epoch 39/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0043
# Epoch 40/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0043
# Epoch 41/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0044
# Epoch 42/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0095 - val_loss: 0.0045
# Epoch 43/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0043
# Epoch 44/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0094 - val_loss: 0.0044
# Epoch 45/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0092 - val_loss: 0.0045
# Epoch 46/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0094 - val_loss: 0.0041
# Epoch 47/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0043
# Epoch 48/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0093 - val_loss: 0.0043
# Epoch 49/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0094 - val_loss: 0.0042
# Epoch 50/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0092 - val_loss: 0.0045
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 297us/step

# %%
fid_NN_1k, std_NN_1k = train_NN_fidelity(X_1k, y_1k)
# Out:
# Epoch 1/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.1734 - val_loss: 0.0140
# Epoch 2/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0242 - val_loss: 0.0095
# Epoch 3/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0173 - val_loss: 0.0079
# Epoch 4/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0150 - val_loss: 0.0071
# Epoch 5/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0137 - val_loss: 0.0062
# Epoch 6/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0130 - val_loss: 0.0058
# Epoch 7/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0124 - val_loss: 0.0054
# Epoch 8/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0121 - val_loss: 0.0051
# Epoch 9/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0118 - val_loss: 0.0050
# Epoch 10/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0116 - val_loss: 0.0049
# Epoch 11/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0115 - val_loss: 0.0048
# Epoch 12/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0112 - val_loss: 0.0047
# Epoch 13/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0111 - val_loss: 0.0048
# Epoch 14/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0111 - val_loss: 0.0047
# Epoch 15/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0109 - val_loss: 0.0046
# Epoch 16/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0108 - val_loss: 0.0043
# Epoch 17/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0106 - val_loss: 0.0043
# Epoch 18/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0105 - val_loss: 0.0043
# Epoch 19/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0104 - val_loss: 0.0043
# Epoch 20/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0105 - val_loss: 0.0043
# Epoch 21/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0104 - val_loss: 0.0042
# Epoch 22/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0103 - val_loss: 0.0047
# Epoch 23/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0103 - val_loss: 0.0043
# Epoch 24/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0103 - val_loss: 0.0043
# Epoch 25/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0102 - val_loss: 0.0045
# Epoch 26/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0101 - val_loss: 0.0043
# Epoch 27/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0101 - val_loss: 0.0043
# Epoch 28/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0101 - val_loss: 0.0042
# Epoch 29/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0101 - val_loss: 0.0043
# Epoch 30/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0100 - val_loss: 0.0045
# Epoch 31/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0099 - val_loss: 0.0043
# Epoch 32/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0099 - val_loss: 0.0042
# Epoch 33/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0098 - val_loss: 0.0042
# Epoch 34/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0099 - val_loss: 0.0044
# Epoch 35/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0099 - val_loss: 0.0041
# Epoch 36/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0098 - val_loss: 0.0042
# Epoch 37/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0097 - val_loss: 0.0042
# Epoch 38/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0098 - val_loss: 0.0042
# Epoch 39/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0098 - val_loss: 0.0042
# Epoch 40/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0097 - val_loss: 0.0044
# Epoch 41/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0096 - val_loss: 0.0042
# Epoch 42/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0098 - val_loss: 0.0043
# Epoch 43/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0097 - val_loss: 0.0043
# Epoch 44/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0097 - val_loss: 0.0042
# Epoch 45/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0097 - val_loss: 0.0041
# Epoch 46/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0096 - val_loss: 0.0042
# Epoch 47/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0096 - val_loss: 0.0043
# Epoch 48/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0096 - val_loss: 0.0046
# Epoch 49/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0096 - val_loss: 0.0040
# Epoch 50/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0043
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 299us/step

# %%
fid_10, std_10 = MLE_Avg_fidelity(data_10, X_10[0:100 ,:], y_10[0:100, :])
fid_20, std_20 = MLE_Avg_fidelity(data_20, X_20[0:100 ,:], y_20[0:100, :])
fid_50, std_50 = MLE_Avg_fidelity(data_50, X_50[0:100 ,:], y_50[0:100, :])
fid_100, std_100 = MLE_Avg_fidelity(data_100, X_100[0:100 ,:], y_100[0:100, :])
fid_1k, std_1k = MLE_Avg_fidelity(data_1k, X_1k[0:100 ,:], y_1k[0:100, :])
fid_5k, std_5k = MLE_Avg_fidelity(data_5k, X_5k[0:100 ,:], y_5k[0:100, :])
fid_10k, std_10k = MLE_Avg_fidelity(data_10k, X_10k[0:100 ,:], y_10k[0:100, :])

# %%
shots = [10,20, 50, 100, 1000, 5000, 10000]
fidelities = [fid_10,fid_20, fid_50, fid_100, fid_1k, fid_5k, fid_10k]
std = [std_10, std_20, std_50, std_100, std_1k, std_5k, std_10k]

#NN fidelities
fidelities_NN = [fid_NN_10,fid_NN_20, fid_NN_50, fid_NN_100, fid_NN_1k, fid_NN_5k, fid_NN_10k]
std_NN =  np.array([std_NN_10, std_NN_20, std_NN_50, std_NN_100, std_NN_1k, std_NN_5k, std_NN_10k])


plt.figure(figsize=(7,5))
plt.errorbar(shots, fidelities, yerr=std, fmt='o-', capsize=5, label="MLE", markersize=6)
plt.errorbar(shots, fidelities_NN, yerr=std_NN, fmt='o-', capsize=5, label="DNN", markersize=6)

plt.xscale('log')
plt.xlabel("Shots per basis (log scale)")
plt.ylabel("Fidelity")
plt.title("Reconstruction Fidelity vs. Shot Count Non-Noisy Measurements 2 Qubits")
plt.ylim(0.6,1.05)
plt.legend()
plt.grid(True, which="both", ls="--", alpha=0.6)
plt.show()
