# %%
import numpy as np
import random
import pandas as pd
import scipy.io
import matplotlib.pyplot as plt
from qiskit.quantum_info import DensityMatrix, random_density_matrix
from qiskit.quantum_info.operators import Operator
import tensorflow as tf

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from scipy.linalg import sqrtm
from scipy.optimize import minimize

import torch
#tensorflow imports
from tensorflow import keras
from keras import layers, losses, Model
import logging
tf.get_logger().setLevel(logging.ERROR)

# %%
data = np.load('../datasets/1k_shots_noisy/2q_noise_0.05_1k_.npz')

# %%
X = data['counts']
y = data['states']

# %%
print(X.shape)
print(y.shape)
# Out:
# (100000, 36)
# (100000, 4, 4)

# %% [markdown]
# # Cholesky MLE

# %%
# First limit the size of X so this actually runs
X_mle = X[0:1000 ,:]
y_mle = y[0:1000, :]
print(X_mle.shape)
# Out:
# (1000, 36)

# %%
shots = data['shots_per_basis']
counts = (X_mle * shots).astype(int)        # freq counts


# Build computational basis projectors for 2 qubits
proj = []
for m in range(4):
    P = np.zeros((4,4), dtype=complex)
    P[m, m] = 1
    proj.append(P)

# Define basis-change unitaries for X, Y, Z on one qubit
H = np.array([[1, 1], [1, -1]]) / np.sqrt(2)
Sdg = np.array([[1, 0], [0, -1j]])
bases = {
    'X': H,
    'Y': Sdg @ H,
    'Z': np.eye(2)
}

settings = []
for b1 in ['X','Y','Z']:
    for b2 in ['X','Y','Z']:
        U = np.kron(bases[b1], bases[b2])
        settings.append(U)

E = []
for U in settings:
    U_dag = U.conj().T
    for P in proj:
        E.append(U_dag @ P @ U)

# Map the cholesky parameterised vector to a PSD trace 1 density matrix
def params_to_rho(params):
    # params: length 16
    L = np.zeros((4,4), dtype=complex)
    idx = 0
    # diagonal entries (real, positive)
    for i in range(4):
        L[i, i] = params[idx]
        idx += 1
    # lower-triangular off-diagonals (real + imag)
    for i in range(1, 4):
        for j in range(i):
            re = params[idx]; im = params[idx+1]
            L[i, j] = re + 1j * im
            idx += 2
    rho = L @ L.conj().T
    return rho / np.trace(rho)

# COmpute NLL
def neg_log_likelihood(params, count):
    rho = params_to_rho(params)
    # avoid log(0) by clipping
    probs = np.array([np.real(np.trace(Ej @ rho)) for Ej in E])
    probs = np.clip(probs, 1e-12, 1.0)
    return -np.sum(count * np.log(probs))


N = X_mle.shape[0]
#initialise the estimator
rho_est = np.zeros((N, 4, 4), dtype=complex)

for i in range(N):
    
    # initial guess: uniform identity
    init = np.zeros(16)
    init[:4] = np.sqrt(1/4)
    
    res = minimize(
        neg_log_likelihood, init, args=(counts[i],),
        method='L-BFGS-B',
        options={'maxiter': 500}
    )
    #reconstruct the density matrix from cholesky decomp
    rho_est[i] = params_to_rho(res.x)

# %%
# Recover target density matrices from y
rho_target = np.zeros((N, 4, 4), dtype=complex)


# compute Fidelity
def fidelity(rho1, rho2):
    sqrt_rho1 = sqrtm(rho1)
    F = np.trace(sqrtm(sqrt_rho1 @ rho2 @ sqrt_rho1))
    return np.real(F)**2

fidelities = np.array([fidelity(rho_est[i], y_mle[i]) for i in range(N)])

mean_fidelity = np.mean(fidelities)
std_fidelity  = np.std(fidelities)
print(f"Mean fidelity: {mean_fidelity:.4f} ± {std_fidelity:.4f}")
# Out:
# Mean fidelity: 0.4725 ± 0.1307

# %% [markdown]
# # Cholesky NN

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, random_state=2)

# %%
def rho_to_alpha(rho):
    # T is lower triangular matrix
    L = np.linalg.cholesky(rho + 1e-14 * np.eye(y[0].shape[0]))
    alpha = []
    # extract the reals on the diagonals
    for i in range(rho.shape[0]):
        alpha.append(np.real(L[i, i]))  # add them to alpha
    
    # Off diagonals, contain real and imag components
    for i in range(1, rho.shape[0]):
        for j in range(i):
            alpha.append(np.real(L[i, j]))
            alpha.append(np.imag(L[i, j]))
    return np.array(alpha)

alphas = np.stack([rho_to_alpha(y[i]) for i in range(len(y))], axis=0)

N_x = X_train.shape[1]
N_alpha = alphas.shape[1]

model = tf.keras.Sequential([
    tf.keras.layers.InputLayer(shape=(N_x,)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(128, activation="relu"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(128, activation="relu"),
    tf.keras.layers.Dense(N_alpha)   
])

model.compile(
    optimizer=tf.keras.optimizers.Adam(1e-3),
    loss="mse",
    metrics=["mse"]
)

history = model.fit(
    X_train, alphas,
    validation_split=0.2,
    epochs=1000,
    batch_size=1000,
)
# Out:
# Epoch 1/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.4939 - mse: 0.4939 - val_loss: 0.1525 - val_mse: 0.1525
# Epoch 2/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1291 - mse: 0.1291 - val_loss: 0.0741 - val_mse: 0.0741
# Epoch 3/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0925 - mse: 0.0925 - val_loss: 0.0596 - val_mse: 0.0596
# Epoch 4/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0777 - mse: 0.0777 - val_loss: 0.0538 - val_mse: 0.0538
# Epoch 5/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0694 - mse: 0.0694 - val_loss: 0.0509 - val_mse: 0.0509
# Epoch 6/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0639 - mse: 0.0639 - val_loss: 0.0493 - val_mse: 0.0493
# Epoch 7/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0599 - mse: 0.0599 - val_loss: 0.0485 - val_mse: 0.0485
# Epoch 8/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0572 - mse: 0.0572 - val_loss: 0.0468 - val_mse: 0.0468
# Epoch 9/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0553 - mse: 0.0553 - val_loss: 0.0458 - val_mse: 0.0458
# Epoch 10/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0537 - mse: 0.0537 - val_loss: 0.0456 - val_mse: 0.0456
# Epoch 11/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0527 - mse: 0.0527 - val_loss: 0.0446 - val_mse: 0.0446
# Epoch 12/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0520 - mse: 0.0520 - val_loss: 0.0447 - val_mse: 0.0447
# Epoch 13/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0515 - mse: 0.0515 - val_loss: 0.0446 - val_mse: 0.0446
# Epoch 14/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0511 - mse: 0.0511 - val_loss: 0.0442 - val_mse: 0.0442
# Epoch 15/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0509 - mse: 0.0509 - val_loss: 0.0447 - val_mse: 0.0447
# Epoch 16/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0507 - mse: 0.0507 - val_loss: 0.0443 - val_mse: 0.0443
# Epoch 17/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0505 - mse: 0.0505 - val_loss: 0.0441 - val_mse: 0.0441
# Epoch 18/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0504 - mse: 0.0504 - val_loss: 0.0442 - val_mse: 0.0442
# Epoch 19/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0503 - mse: 0.0503 - val_loss: 0.0440 - val_mse: 0.0440
# Epoch 20/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0504 - mse: 0.0504 - val_loss: 0.0445 - val_mse: 0.0445
# Epoch 21/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0501 - mse: 0.0501 - val_loss: 0.0439 - val_mse: 0.0439
# Epoch 22/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0501 - mse: 0.0501 - val_loss: 0.0440 - val_mse: 0.0440
# Epoch 23/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0501 - mse: 0.0501 - val_loss: 0.0438 - val_mse: 0.0438
# Epoch 24/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0500 - mse: 0.0500 - val_loss: 0.0433 - val_mse: 0.0433
# Epoch 25/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0500 - mse: 0.0500 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 26/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0498 - mse: 0.0498 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 27/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0499 - mse: 0.0499 - val_loss: 0.0443 - val_mse: 0.0443
# Epoch 28/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0499 - mse: 0.0499 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 29/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0499 - mse: 0.0499 - val_loss: 0.0441 - val_mse: 0.0441
# Epoch 30/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0498 - mse: 0.0498 - val_loss: 0.0442 - val_mse: 0.0442
# Epoch 31/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0497 - mse: 0.0497 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 32/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0498 - mse: 0.0498 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 33/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0497 - mse: 0.0497 - val_loss: 0.0432 - val_mse: 0.0432
# Epoch 34/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0497 - mse: 0.0497 - val_loss: 0.0441 - val_mse: 0.0441
# Epoch 35/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0497 - mse: 0.0497 - val_loss: 0.0442 - val_mse: 0.0442
# Epoch 36/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0496 - mse: 0.0496 - val_loss: 0.0438 - val_mse: 0.0438
# Epoch 37/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0497 - mse: 0.0497 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 38/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0496 - mse: 0.0496 - val_loss: 0.0439 - val_mse: 0.0439
# Epoch 39/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0496 - mse: 0.0496 - val_loss: 0.0441 - val_mse: 0.0441
# Epoch 40/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0497 - mse: 0.0497 - val_loss: 0.0439 - val_mse: 0.0439
# Epoch 41/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0497 - mse: 0.0497 - val_loss: 0.0441 - val_mse: 0.0441
# Epoch 42/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0496 - mse: 0.0496 - val_loss: 0.0439 - val_mse: 0.0439
# Epoch 43/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0496 - mse: 0.0496 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 44/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0497 - mse: 0.0497 - val_loss: 0.0430 - val_mse: 0.0430
# Epoch 45/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0497 - mse: 0.0497 - val_loss: 0.0438 - val_mse: 0.0438
# Epoch 46/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0496 - mse: 0.0496 - val_loss: 0.0439 - val_mse: 0.0439
# Epoch 47/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0495 - mse: 0.0495 - val_loss: 0.0441 - val_mse: 0.0441
# Epoch 48/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0495 - mse: 0.0495 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 49/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0495 - mse: 0.0495 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 50/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0496 - mse: 0.0496 - val_loss: 0.0442 - val_mse: 0.0442
# Epoch 51/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0495 - mse: 0.0495 - val_loss: 0.0440 - val_mse: 0.0440
# Epoch 52/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0495 - mse: 0.0495 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 53/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0494 - mse: 0.0494 - val_loss: 0.0442 - val_mse: 0.0442
# Epoch 54/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0495 - mse: 0.0495 - val_loss: 0.0441 - val_mse: 0.0441
# Epoch 55/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0495 - mse: 0.0495 - val_loss: 0.0444 - val_mse: 0.0444
# Epoch 56/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0495 - mse: 0.0495 - val_loss: 0.0430 - val_mse: 0.0430
# Epoch 57/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0495 - mse: 0.0495 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 58/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0495 - mse: 0.0495 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 59/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0495 - mse: 0.0495 - val_loss: 0.0439 - val_mse: 0.0439
# Epoch 60/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0494 - mse: 0.0494 - val_loss: 0.0439 - val_mse: 0.0439
# Epoch 61/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0493 - mse: 0.0493 - val_loss: 0.0443 - val_mse: 0.0443
# Epoch 62/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0495 - mse: 0.0495 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 63/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0494 - mse: 0.0494 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 64/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0493 - mse: 0.0493 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 65/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0494 - mse: 0.0494 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 66/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0494 - mse: 0.0494 - val_loss: 0.0441 - val_mse: 0.0441
# Epoch 67/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0494 - mse: 0.0494 - val_loss: 0.0440 - val_mse: 0.0440
# Epoch 68/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0494 - mse: 0.0494 - val_loss: 0.0433 - val_mse: 0.0433
# Epoch 69/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0493 - mse: 0.0493 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 70/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0494 - mse: 0.0494 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 71/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0494 - mse: 0.0494 - val_loss: 0.0430 - val_mse: 0.0430
# Epoch 72/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0494 - mse: 0.0494 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 73/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0493 - mse: 0.0493 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 74/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0493 - mse: 0.0493 - val_loss: 0.0429 - val_mse: 0.0429
# Epoch 75/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0493 - mse: 0.0493 - val_loss: 0.0439 - val_mse: 0.0439
# Epoch 76/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0493 - mse: 0.0493 - val_loss: 0.0428 - val_mse: 0.0428
# Epoch 77/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0492 - mse: 0.0492 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 78/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0492 - mse: 0.0492 - val_loss: 0.0433 - val_mse: 0.0433
# Epoch 79/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0492 - mse: 0.0492 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 80/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0493 - mse: 0.0493 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 81/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0493 - mse: 0.0493 - val_loss: 0.0429 - val_mse: 0.0429
# Epoch 82/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0492 - mse: 0.0492 - val_loss: 0.0439 - val_mse: 0.0439
# Epoch 83/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0492 - mse: 0.0492 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 84/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0492 - mse: 0.0492 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 85/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0493 - mse: 0.0493 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 86/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0492 - mse: 0.0492 - val_loss: 0.0431 - val_mse: 0.0431
# Epoch 87/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0492 - mse: 0.0492 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 88/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0493 - mse: 0.0493 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 89/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0493 - mse: 0.0493 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 90/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0492 - mse: 0.0492 - val_loss: 0.0432 - val_mse: 0.0432
# Epoch 91/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0493 - mse: 0.0493 - val_loss: 0.0438 - val_mse: 0.0438
# Epoch 92/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0492 - mse: 0.0492 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 93/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0491 - mse: 0.0491 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 94/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0491 - mse: 0.0491 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 95/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0492 - mse: 0.0492 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 96/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0491 - mse: 0.0491 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 97/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0492 - mse: 0.0492 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 98/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0492 - mse: 0.0492 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 99/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0491 - mse: 0.0491 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 100/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0492 - mse: 0.0492 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 101/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0492 - mse: 0.0492 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 102/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0491 - mse: 0.0491 - val_loss: 0.0433 - val_mse: 0.0433
# Epoch 103/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0492 - mse: 0.0492 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 104/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0492 - mse: 0.0492 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 105/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0492 - mse: 0.0492 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 106/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0491 - mse: 0.0491 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 107/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0491 - mse: 0.0491 - val_loss: 0.0433 - val_mse: 0.0433
# Epoch 108/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0491 - mse: 0.0491 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 109/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0492 - mse: 0.0492 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 110/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0492 - mse: 0.0492 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 111/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0492 - mse: 0.0492 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 112/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0492 - mse: 0.0492 - val_loss: 0.0433 - val_mse: 0.0433
# Epoch 113/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0491 - mse: 0.0491 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 114/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0491 - mse: 0.0491 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 115/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0491 - mse: 0.0491 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 116/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0491 - mse: 0.0491 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 117/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0491 - mse: 0.0491 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 118/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0492 - mse: 0.0492 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 119/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0491 - mse: 0.0491 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 120/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0492 - mse: 0.0492 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 121/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0491 - mse: 0.0491 - val_loss: 0.0433 - val_mse: 0.0433
# Epoch 122/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0492 - mse: 0.0492 - val_loss: 0.0431 - val_mse: 0.0431
# Epoch 123/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0492 - mse: 0.0492 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 124/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0492 - mse: 0.0492 - val_loss: 0.0433 - val_mse: 0.0433
# Epoch 125/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0491 - mse: 0.0491 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 126/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0491 - mse: 0.0491 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 127/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0491 - mse: 0.0491 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 128/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0490 - mse: 0.0490 - val_loss: 0.0433 - val_mse: 0.0433
# Epoch 129/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0490 - mse: 0.0490 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 130/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0491 - mse: 0.0491 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 131/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0492 - mse: 0.0492 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 132/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0490 - mse: 0.0490 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 133/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0491 - mse: 0.0491 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 134/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0490 - mse: 0.0490 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 135/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0491 - mse: 0.0491 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 136/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0491 - mse: 0.0491 - val_loss: 0.0433 - val_mse: 0.0433
# Epoch 137/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0491 - mse: 0.0491 - val_loss: 0.0433 - val_mse: 0.0433
# Epoch 138/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0491 - mse: 0.0491 - val_loss: 0.0433 - val_mse: 0.0433
# Epoch 139/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0491 - mse: 0.0491 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 140/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0491 - mse: 0.0491 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 141/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0491 - mse: 0.0491 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 142/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0491 - mse: 0.0491 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 143/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0491 - mse: 0.0491 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 144/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0490 - mse: 0.0490 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 145/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0491 - mse: 0.0491 - val_loss: 0.0432 - val_mse: 0.0432
# Epoch 146/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0491 - mse: 0.0491 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 147/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0490 - mse: 0.0490 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 148/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0491 - mse: 0.0491 - val_loss: 0.0433 - val_mse: 0.0433
# Epoch 149/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0491 - mse: 0.0491 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 150/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0491 - mse: 0.0491 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 151/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0490 - mse: 0.0490 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 152/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0491 - mse: 0.0491 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 153/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0491 - mse: 0.0491 - val_loss: 0.0438 - val_mse: 0.0438
# Epoch 154/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0490 - mse: 0.0490 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 155/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0490 - mse: 0.0490 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 156/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0491 - mse: 0.0491 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 157/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0490 - mse: 0.0490 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 158/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0490 - mse: 0.0490 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 159/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0490 - mse: 0.0490 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 160/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0491 - mse: 0.0491 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 161/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0490 - mse: 0.0490 - val_loss: 0.0432 - val_mse: 0.0432
# Epoch 162/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0491 - mse: 0.0491 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 163/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0491 - mse: 0.0491 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 164/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0490 - mse: 0.0490 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 165/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0491 - mse: 0.0491 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 166/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0490 - mse: 0.0490 - val_loss: 0.0433 - val_mse: 0.0433
# Epoch 167/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0490 - mse: 0.0490 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 168/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0490 - mse: 0.0490 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 169/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0490 - mse: 0.0490 - val_loss: 0.0432 - val_mse: 0.0432
# Epoch 170/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0490 - mse: 0.0490 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 171/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0490 - mse: 0.0490 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 172/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0490 - mse: 0.0490 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 173/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0490 - mse: 0.0490 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 174/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0490 - mse: 0.0490 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 175/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0491 - mse: 0.0491 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 176/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0490 - mse: 0.0490 - val_loss: 0.0432 - val_mse: 0.0432
# Epoch 177/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0489 - mse: 0.0489 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 178/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0490 - mse: 0.0490 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 179/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0490 - mse: 0.0490 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 180/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0490 - mse: 0.0490 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 181/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0490 - mse: 0.0490 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 182/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0491 - mse: 0.0491 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 183/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0490 - mse: 0.0490 - val_loss: 0.0433 - val_mse: 0.0433
# Epoch 184/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0490 - mse: 0.0490 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 185/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0490 - mse: 0.0490 - val_loss: 0.0433 - val_mse: 0.0433
# Epoch 186/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0491 - mse: 0.0491 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 187/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0491 - mse: 0.0491 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 188/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0490 - mse: 0.0490 - val_loss: 0.0433 - val_mse: 0.0433
# Epoch 189/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0490 - mse: 0.0490 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 190/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0490 - mse: 0.0490 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 191/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0490 - mse: 0.0490 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 192/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0490 - mse: 0.0490 - val_loss: 0.0432 - val_mse: 0.0432
# Epoch 193/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0489 - mse: 0.0489 - val_loss: 0.0433 - val_mse: 0.0433
# Epoch 194/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0490 - mse: 0.0490 - val_loss: 0.0433 - val_mse: 0.0433
# Epoch 195/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0490 - mse: 0.0490 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 196/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0491 - mse: 0.0491 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 197/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0490 - mse: 0.0490 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 198/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0489 - mse: 0.0489 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 199/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0489 - mse: 0.0489 - val_loss: 0.0433 - val_mse: 0.0433
# Epoch 200/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0490 - mse: 0.0490 - val_loss: 0.0432 - val_mse: 0.0432
# Epoch 201/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0490 - mse: 0.0490 - val_loss: 0.0432 - val_mse: 0.0432
# Epoch 202/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0490 - mse: 0.0490 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 203/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0489 - mse: 0.0489 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 204/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0490 - mse: 0.0490 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 205/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0490 - mse: 0.0490 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 206/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0490 - mse: 0.0490 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 207/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0489 - mse: 0.0489 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 208/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0490 - mse: 0.0490 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 209/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0490 - mse: 0.0490 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 210/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0490 - mse: 0.0490 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 211/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0490 - mse: 0.0490 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 212/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0490 - mse: 0.0490 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 213/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0489 - mse: 0.0489 - val_loss: 0.0432 - val_mse: 0.0432
# Epoch 214/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0489 - mse: 0.0489 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 215/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0489 - mse: 0.0489 - val_loss: 0.0433 - val_mse: 0.0433
# Epoch 216/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0489 - mse: 0.0489 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 217/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0490 - mse: 0.0490 - val_loss: 0.0433 - val_mse: 0.0433
# Epoch 218/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0489 - mse: 0.0489 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 219/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0489 - mse: 0.0489 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 220/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0490 - mse: 0.0490 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 221/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0490 - mse: 0.0490 - val_loss: 0.0438 - val_mse: 0.0438
# Epoch 222/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0489 - mse: 0.0489 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 223/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0489 - mse: 0.0489 - val_loss: 0.0433 - val_mse: 0.0433
# Epoch 224/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0489 - mse: 0.0489 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 225/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0489 - mse: 0.0489 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 226/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0490 - mse: 0.0490 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 227/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0488 - mse: 0.0488 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 228/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0489 - mse: 0.0489 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 229/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0489 - mse: 0.0489 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 230/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0489 - mse: 0.0489 - val_loss: 0.0433 - val_mse: 0.0433
# Epoch 231/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0490 - mse: 0.0490 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 232/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0489 - mse: 0.0489 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 233/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0489 - mse: 0.0489 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 234/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0489 - mse: 0.0489 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 235/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0488 - mse: 0.0488 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 236/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0489 - mse: 0.0489 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 237/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0488 - mse: 0.0488 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 238/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0489 - mse: 0.0489 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 239/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0489 - mse: 0.0489 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 240/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0489 - mse: 0.0489 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 241/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0489 - mse: 0.0489 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 242/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0489 - mse: 0.0489 - val_loss: 0.0433 - val_mse: 0.0433
# Epoch 243/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0489 - mse: 0.0489 - val_loss: 0.0433 - val_mse: 0.0433
# Epoch 244/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0488 - mse: 0.0488 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 245/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0489 - mse: 0.0489 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 246/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0489 - mse: 0.0489 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 247/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0489 - mse: 0.0489 - val_loss: 0.0438 - val_mse: 0.0438
# Epoch 248/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0489 - mse: 0.0489 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 249/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0488 - mse: 0.0488 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 250/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0489 - mse: 0.0489 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 251/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0489 - mse: 0.0489 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 252/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0488 - mse: 0.0488 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 253/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0488 - mse: 0.0488 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 254/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0489 - mse: 0.0489 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 255/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0489 - mse: 0.0489 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 256/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0488 - mse: 0.0488 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 257/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0488 - mse: 0.0488 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 258/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0489 - mse: 0.0489 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 259/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0488 - mse: 0.0488 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 260/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0489 - mse: 0.0489 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 261/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0489 - mse: 0.0489 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 262/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0490 - mse: 0.0490 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 263/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0488 - mse: 0.0488 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 264/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0488 - mse: 0.0488 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 265/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0489 - mse: 0.0489 - val_loss: 0.0438 - val_mse: 0.0438
# Epoch 266/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0489 - mse: 0.0489 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 267/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0488 - mse: 0.0488 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 268/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0489 - mse: 0.0489 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 269/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0488 - mse: 0.0488 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 270/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0488 - mse: 0.0488 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 271/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0489 - mse: 0.0489 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 272/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0488 - mse: 0.0488 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 273/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0489 - mse: 0.0489 - val_loss: 0.0433 - val_mse: 0.0433
# Epoch 274/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0488 - mse: 0.0488 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 275/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0488 - mse: 0.0488 - val_loss: 0.0433 - val_mse: 0.0433
# Epoch 276/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0488 - mse: 0.0488 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 277/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0489 - mse: 0.0489 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 278/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0489 - mse: 0.0489 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 279/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0489 - mse: 0.0489 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 280/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0488 - mse: 0.0488 - val_loss: 0.0438 - val_mse: 0.0438
# Epoch 281/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0488 - mse: 0.0488 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 282/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0488 - mse: 0.0488 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 283/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0488 - mse: 0.0488 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 284/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0488 - mse: 0.0488 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 285/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0488 - mse: 0.0488 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 286/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0488 - mse: 0.0488 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 287/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0488 - mse: 0.0488 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 288/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0488 - mse: 0.0488 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 289/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0487 - mse: 0.0487 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 290/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0488 - mse: 0.0488 - val_loss: 0.0433 - val_mse: 0.0433
# Epoch 291/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0488 - mse: 0.0488 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 292/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0488 - mse: 0.0488 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 293/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0488 - mse: 0.0488 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 294/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0488 - mse: 0.0488 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 295/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0487 - mse: 0.0487 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 296/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0488 - mse: 0.0488 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 297/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0488 - mse: 0.0488 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 298/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0488 - mse: 0.0488 - val_loss: 0.0439 - val_mse: 0.0439
# Epoch 299/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0488 - mse: 0.0488 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 300/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0488 - mse: 0.0488 - val_loss: 0.0432 - val_mse: 0.0432
# Epoch 301/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0488 - mse: 0.0488 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 302/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0488 - mse: 0.0488 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 303/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0488 - mse: 0.0488 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 304/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0488 - mse: 0.0488 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 305/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0489 - mse: 0.0489 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 306/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0488 - mse: 0.0488 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 307/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0488 - mse: 0.0488 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 308/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0488 - mse: 0.0488 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 309/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0488 - mse: 0.0488 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 310/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0487 - mse: 0.0487 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 311/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0487 - mse: 0.0487 - val_loss: 0.0433 - val_mse: 0.0433
# Epoch 312/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0487 - mse: 0.0487 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 313/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0488 - mse: 0.0488 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 314/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0487 - mse: 0.0487 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 315/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0487 - mse: 0.0487 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 316/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0488 - mse: 0.0488 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 317/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0487 - mse: 0.0487 - val_loss: 0.0438 - val_mse: 0.0438
# Epoch 318/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0487 - mse: 0.0487 - val_loss: 0.0438 - val_mse: 0.0438
# Epoch 319/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0488 - mse: 0.0488 - val_loss: 0.0438 - val_mse: 0.0438
# Epoch 320/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0487 - mse: 0.0487 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 321/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0488 - mse: 0.0488 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 322/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0487 - mse: 0.0487 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 323/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0487 - mse: 0.0487 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 324/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0488 - mse: 0.0488 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 325/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0487 - mse: 0.0487 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 326/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0487 - mse: 0.0487 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 327/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0488 - mse: 0.0488 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 328/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0487 - mse: 0.0487 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 329/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0487 - mse: 0.0487 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 330/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0487 - mse: 0.0487 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 331/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0487 - mse: 0.0487 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 332/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0487 - mse: 0.0487 - val_loss: 0.0438 - val_mse: 0.0438
# Epoch 333/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0486 - mse: 0.0486 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 334/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0487 - mse: 0.0487 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 335/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0487 - mse: 0.0487 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 336/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0488 - mse: 0.0488 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 337/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0487 - mse: 0.0487 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 338/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0487 - mse: 0.0487 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 339/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0487 - mse: 0.0487 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 340/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0488 - mse: 0.0488 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 341/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0487 - mse: 0.0487 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 342/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0487 - mse: 0.0487 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 343/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0487 - mse: 0.0487 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 344/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0486 - mse: 0.0486 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 345/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0487 - mse: 0.0487 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 346/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0488 - mse: 0.0488 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 347/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0487 - mse: 0.0487 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 348/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0487 - mse: 0.0487 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 349/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0487 - mse: 0.0487 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 350/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0488 - mse: 0.0488 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 351/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0487 - mse: 0.0487 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 352/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0487 - mse: 0.0487 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 353/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0487 - mse: 0.0487 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 354/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0487 - mse: 0.0487 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 355/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.0487 - mse: 0.0487 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 356/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0486 - mse: 0.0486 - val_loss: 0.0438 - val_mse: 0.0438
# Epoch 357/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0487 - mse: 0.0487 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 358/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0487 - mse: 0.0487 - val_loss: 0.0433 - val_mse: 0.0433
# Epoch 359/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0487 - mse: 0.0487 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 360/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0488 - mse: 0.0488 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 361/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0487 - mse: 0.0487 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 362/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0487 - mse: 0.0487 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 363/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0487 - mse: 0.0487 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 364/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0486 - mse: 0.0486 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 365/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0487 - mse: 0.0487 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 366/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0488 - mse: 0.0488 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 367/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0487 - mse: 0.0487 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 368/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0487 - mse: 0.0487 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 369/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0487 - mse: 0.0487 - val_loss: 0.0438 - val_mse: 0.0438
# Epoch 370/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0487 - mse: 0.0487 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 371/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0487 - mse: 0.0487 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 372/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0487 - mse: 0.0487 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 373/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0486 - mse: 0.0486 - val_loss: 0.0438 - val_mse: 0.0438
# Epoch 374/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0487 - mse: 0.0487 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 375/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0487 - mse: 0.0487 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 376/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0486 - mse: 0.0486 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 377/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0486 - mse: 0.0486 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 378/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0486 - mse: 0.0486 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 379/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0486 - mse: 0.0486 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 380/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0487 - mse: 0.0487 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 381/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0487 - mse: 0.0487 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 382/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0487 - mse: 0.0487 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 383/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0486 - mse: 0.0486 - val_loss: 0.0438 - val_mse: 0.0438
# Epoch 384/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0486 - mse: 0.0486 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 385/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0487 - mse: 0.0487 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 386/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0487 - mse: 0.0487 - val_loss: 0.0438 - val_mse: 0.0438
# Epoch 387/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0487 - mse: 0.0487 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 388/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0486 - mse: 0.0486 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 389/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0486 - mse: 0.0486 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 390/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0487 - mse: 0.0487 - val_loss: 0.0438 - val_mse: 0.0438
# Epoch 391/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0486 - mse: 0.0486 - val_loss: 0.0438 - val_mse: 0.0438
# Epoch 392/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0486 - mse: 0.0486 - val_loss: 0.0439 - val_mse: 0.0439
# Epoch 393/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0487 - mse: 0.0487 - val_loss: 0.0434 - val_mse: 0.0434
# Epoch 394/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0486 - mse: 0.0486 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 395/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0487 - mse: 0.0487 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 396/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0486 - mse: 0.0486 - val_loss: 0.0439 - val_mse: 0.0439
# Epoch 397/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0487 - mse: 0.0487 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 398/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0485 - mse: 0.0485 - val_loss: 0.0439 - val_mse: 0.0439
# Epoch 399/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0486 - mse: 0.0486 - val_loss: 0.0440 - val_mse: 0.0440
# Epoch 400/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0486 - mse: 0.0486 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 401/1000
# ...
# Epoch 868/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 869/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0485 - mse: 0.0485 - val_loss: 0.0439 - val_mse: 0.0439
# Epoch 870/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0485 - mse: 0.0485 - val_loss: 0.0439 - val_mse: 0.0439
# Epoch 871/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0438 - val_mse: 0.0438
# Epoch 872/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0485 - mse: 0.0485 - val_loss: 0.0438 - val_mse: 0.0438
# Epoch 873/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0486 - mse: 0.0486 - val_loss: 0.0438 - val_mse: 0.0438
# Epoch 874/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0485 - mse: 0.0485 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 875/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0438 - val_mse: 0.0438
# Epoch 876/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0485 - mse: 0.0485 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 877/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0485 - mse: 0.0485 - val_loss: 0.0438 - val_mse: 0.0438
# Epoch 878/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0438 - val_mse: 0.0438
# Epoch 879/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0438 - val_mse: 0.0438
# Epoch 880/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0485 - mse: 0.0485 - val_loss: 0.0440 - val_mse: 0.0440
# Epoch 881/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0485 - mse: 0.0485 - val_loss: 0.0438 - val_mse: 0.0438
# Epoch 882/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0441 - val_mse: 0.0441
# Epoch 883/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0485 - mse: 0.0485 - val_loss: 0.0438 - val_mse: 0.0438
# Epoch 884/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0485 - mse: 0.0485 - val_loss: 0.0439 - val_mse: 0.0439
# Epoch 885/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0483 - mse: 0.0483 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 886/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0485 - mse: 0.0485 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 887/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 888/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0485 - mse: 0.0485 - val_loss: 0.0438 - val_mse: 0.0438
# Epoch 889/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0485 - mse: 0.0485 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 890/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0485 - mse: 0.0485 - val_loss: 0.0438 - val_mse: 0.0438
# Epoch 891/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0485 - mse: 0.0485 - val_loss: 0.0439 - val_mse: 0.0439
# Epoch 892/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0485 - mse: 0.0485 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 893/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0485 - mse: 0.0485 - val_loss: 0.0441 - val_mse: 0.0441
# Epoch 894/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0485 - mse: 0.0485 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 895/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0439 - val_mse: 0.0439
# Epoch 896/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0486 - mse: 0.0486 - val_loss: 0.0439 - val_mse: 0.0439
# Epoch 897/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0438 - val_mse: 0.0438
# Epoch 898/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0485 - mse: 0.0485 - val_loss: 0.0438 - val_mse: 0.0438
# Epoch 899/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0483 - mse: 0.0483 - val_loss: 0.0442 - val_mse: 0.0442
# Epoch 900/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0483 - mse: 0.0483 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 901/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0485 - mse: 0.0485 - val_loss: 0.0439 - val_mse: 0.0439
# Epoch 902/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0439 - val_mse: 0.0439
# Epoch 903/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0485 - mse: 0.0485 - val_loss: 0.0438 - val_mse: 0.0438
# Epoch 904/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 905/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0438 - val_mse: 0.0438
# Epoch 906/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0438 - val_mse: 0.0438
# Epoch 907/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0485 - mse: 0.0485 - val_loss: 0.0439 - val_mse: 0.0439
# Epoch 908/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0438 - val_mse: 0.0438
# Epoch 909/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0439 - val_mse: 0.0439
# Epoch 910/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0438 - val_mse: 0.0438
# Epoch 911/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0439 - val_mse: 0.0439
# Epoch 912/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0439 - val_mse: 0.0439
# Epoch 913/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0485 - mse: 0.0485 - val_loss: 0.0439 - val_mse: 0.0439
# Epoch 914/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0438 - val_mse: 0.0438
# Epoch 915/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 916/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0440 - val_mse: 0.0440
# Epoch 917/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0438 - val_mse: 0.0438
# Epoch 918/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0439 - val_mse: 0.0439
# Epoch 919/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0485 - mse: 0.0485 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 920/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0485 - mse: 0.0485 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 921/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0485 - mse: 0.0485 - val_loss: 0.0438 - val_mse: 0.0438
# Epoch 922/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0439 - val_mse: 0.0439
# Epoch 923/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0486 - mse: 0.0486 - val_loss: 0.0439 - val_mse: 0.0439
# Epoch 924/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0485 - mse: 0.0485 - val_loss: 0.0438 - val_mse: 0.0438
# Epoch 925/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0438 - val_mse: 0.0438
# Epoch 926/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0485 - mse: 0.0485 - val_loss: 0.0439 - val_mse: 0.0439
# Epoch 927/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0438 - val_mse: 0.0438
# Epoch 928/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0439 - val_mse: 0.0439
# Epoch 929/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 930/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 931/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0438 - val_mse: 0.0438
# Epoch 932/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0485 - mse: 0.0485 - val_loss: 0.0438 - val_mse: 0.0438
# Epoch 933/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0485 - mse: 0.0485 - val_loss: 0.0440 - val_mse: 0.0440
# Epoch 934/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 935/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 936/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0485 - mse: 0.0485 - val_loss: 0.0438 - val_mse: 0.0438
# Epoch 937/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0485 - mse: 0.0485 - val_loss: 0.0438 - val_mse: 0.0438
# Epoch 938/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0440 - val_mse: 0.0440
# Epoch 939/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0483 - mse: 0.0483 - val_loss: 0.0439 - val_mse: 0.0439
# Epoch 940/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0438 - val_mse: 0.0438
# Epoch 941/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0438 - val_mse: 0.0438
# Epoch 942/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0486 - mse: 0.0486 - val_loss: 0.0438 - val_mse: 0.0438
# Epoch 943/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0439 - val_mse: 0.0439
# Epoch 944/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0485 - mse: 0.0485 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 945/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0483 - mse: 0.0483 - val_loss: 0.0439 - val_mse: 0.0439
# Epoch 946/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0483 - mse: 0.0483 - val_loss: 0.0439 - val_mse: 0.0439
# Epoch 947/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0438 - val_mse: 0.0438
# Epoch 948/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 949/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0439 - val_mse: 0.0439
# Epoch 950/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0485 - mse: 0.0485 - val_loss: 0.0438 - val_mse: 0.0438
# Epoch 951/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0439 - val_mse: 0.0439
# Epoch 952/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0485 - mse: 0.0485 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 953/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0485 - mse: 0.0485 - val_loss: 0.0438 - val_mse: 0.0438
# Epoch 954/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0485 - mse: 0.0485 - val_loss: 0.0441 - val_mse: 0.0441
# Epoch 955/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0439 - val_mse: 0.0439
# Epoch 956/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0438 - val_mse: 0.0438
# Epoch 957/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0441 - val_mse: 0.0441
# Epoch 958/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0439 - val_mse: 0.0439
# Epoch 959/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0485 - mse: 0.0485 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 960/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0485 - mse: 0.0485 - val_loss: 0.0438 - val_mse: 0.0438
# Epoch 961/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0438 - val_mse: 0.0438
# Epoch 962/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0483 - mse: 0.0483 - val_loss: 0.0438 - val_mse: 0.0438
# Epoch 963/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0435 - val_mse: 0.0435
# Epoch 964/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 965/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0440 - val_mse: 0.0440
# Epoch 966/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0438 - val_mse: 0.0438
# Epoch 967/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0439 - val_mse: 0.0439
# Epoch 968/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0439 - val_mse: 0.0439
# Epoch 969/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0485 - mse: 0.0485 - val_loss: 0.0438 - val_mse: 0.0438
# Epoch 970/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0485 - mse: 0.0485 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 971/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 972/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0441 - val_mse: 0.0441
# Epoch 973/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0440 - val_mse: 0.0440
# Epoch 974/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0438 - val_mse: 0.0438
# Epoch 975/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 976/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0485 - mse: 0.0485 - val_loss: 0.0438 - val_mse: 0.0438
# Epoch 977/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0439 - val_mse: 0.0439
# Epoch 978/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0438 - val_mse: 0.0438
# Epoch 979/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0485 - mse: 0.0485 - val_loss: 0.0440 - val_mse: 0.0440
# Epoch 980/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0485 - mse: 0.0485 - val_loss: 0.0439 - val_mse: 0.0439
# Epoch 981/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0439 - val_mse: 0.0439
# Epoch 982/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0439 - val_mse: 0.0439
# Epoch 983/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0485 - mse: 0.0485 - val_loss: 0.0438 - val_mse: 0.0438
# Epoch 984/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0439 - val_mse: 0.0439
# Epoch 985/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0439 - val_mse: 0.0439
# Epoch 986/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0436 - val_mse: 0.0436
# Epoch 987/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0485 - mse: 0.0485 - val_loss: 0.0438 - val_mse: 0.0438
# Epoch 988/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0439 - val_mse: 0.0439
# Epoch 989/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0485 - mse: 0.0485 - val_loss: 0.0441 - val_mse: 0.0441
# Epoch 990/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0485 - mse: 0.0485 - val_loss: 0.0440 - val_mse: 0.0440
# Epoch 991/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0438 - val_mse: 0.0438
# Epoch 992/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0440 - val_mse: 0.0440
# Epoch 993/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0439 - val_mse: 0.0439
# Epoch 994/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 995/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0438 - val_mse: 0.0438
# Epoch 996/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0485 - mse: 0.0485 - val_loss: 0.0438 - val_mse: 0.0438
# Epoch 997/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0438 - val_mse: 0.0438
# Epoch 998/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0439 - val_mse: 0.0439
# Epoch 999/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0484 - mse: 0.0484 - val_loss: 0.0440 - val_mse: 0.0440
# Epoch 1000/1000
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0485 - mse: 0.0485 - val_loss: 0.0437 - val_mse: 0.0437

# %%
def alpha_to_rho(alpha):
    """Convert batch of alpha vectors to density matrices using Cholesky."""
    N = alpha.shape[0]
    rho = np.zeros((N, 4, 4), dtype=np.complex64)
    for i in range(N):
        a = alpha[i]
        L = np.zeros((4, 4), dtype=np.complex64)
        idx = 0
        for j in range(4):
            L[j, j] = a[idx]
            idx += 1
        for j in range(1, 4):
            for k in range(j):
                re = a[idx]
                im = a[idx + 1]
                L[j, k] = re + 1j * im
                idx += 2
        rho_i = L @ L.conj().T
        rho[i] = rho_i / np.trace(rho_i)
    return rho

def reconstruct_true_rho(y):
    """Convert vectorized real+imag back to complex 4x4 matrices."""
    N = y.shape[0]
    real = y[:, :16].reshape(N, 4, 4)
    imag = y[:, 16:].reshape(N, 4, 4)
    return real + 1j * imag

def fidelity(rho1, rho2):
    """
    Uhlmann fidelity between two density matrices.
    inputs: the two density matrices to be compares
    """
    sqrt_rho1 = sqrtm(rho1)
    product = sqrt_rho1 @ rho2 @ sqrt_rho1
    sqrt_product = sqrtm(product)
    F = np.trace(sqrt_product)
    return np.real(F)**2


alpha_pred = model.predict(X_test)      
rho_pred = alpha_to_rho(alpha_pred)  
rho_true = y_test

# Compute fidelities
fidelities = np.array([
    fidelity(rho_pred[i], rho_true[i])
    for i in range(len(rho_pred))
])

# Summary
mean_fid = np.mean(fidelities)
std_fid = np.std(fidelities)
print(f"Test Set Fidelity: {mean_fid:.4f} ± {std_fid:.4f}")
# Out:
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 297us/step
# Test Set Fidelity: 0.2935 ± 0.1633

# %% [markdown]
# #

# %%
def rho_to_alpha(rho):
    """
    Convert a (d x d) density matrix rho into its "Cholesky parameters" alpha.
    """
    L = np.linalg.cholesky(rho)
    d = rho.shape[0]
    alpha = []
    # diagonal (real, >0)
    for i in range(d):
        alpha.append(np.real(L[i, i]))
    # strictly lower triangle (real + imag)
    for i in range(1, d):
        for j in range(i):
            alpha.append(np.real(L[i, j]))
            alpha.append(np.imag(L[i, j]))
    return np.array(alpha, dtype=np.float32)

def fidelity(rho1, rho2):
    A = sqrtm(rho1)
    return np.real(np.trace(sqrtm(A @ rho2 @ A)))**2


def tf_sqrtm_psd(A):
    """
    Compute principal sqrt of Hermitian PSD A (batch,d,d) via eigendecomposition.
    """
    
    eigvals, eigvecs = tf.linalg.eigh(A)

    eigvals = tf.math.real(eigvals)
    eigvals = tf.clip_by_value(eigvals, 0.0, tf.reduce_max(eigvals))
    sqrtvals = tf.sqrt(eigvals)
    D = tf.cast(tf.linalg.diag(sqrtvals), tf.complex64)
    
    return eigvecs @ D @ tf.linalg.adjoint(eigvecs)

def tf_alpha_to_rho(alpha, d):
    """
    Map real alpha (batch, N_alpha) -> complex density matrices (batch, d, d).
    Enforces positivity via a softplus on the Cholesky diag.
    """
    batch = tf.shape(alpha)[0]
    # split diag vs off-diag
    raw_diag = alpha[:, :d] 
    off_vals  = alpha[:, d:] 

    # start zero L
    L = tf.zeros((batch, d, d), tf.complex64)

    diag_pos = tf.nn.softplus(raw_diag) + 1e-6 
    diag_c   = tf.cast(diag_pos, tf.complex64)
    L = tf.linalg.set_diag(L, diag_c)

    idx = 0
    for i in range(1, d):
        for j in range(i):
            re = off_vals[:, idx]
            im = off_vals[:, idx+1]
            idx += 2
            cij = (tf.cast(re, tf.complex64)
                   + 1j * tf.cast(im, tf.complex64))
            cij = tf.reshape(cij, (batch, 1, 1))

            # mask with a one-hot at (i,j)
            flat = tf.one_hot(i*d + j, d*d, dtype=tf.complex64)
            mask = tf.reshape(flat, (d, d))[None, :, :]

            L = L + cij * mask

    rho = L @ tf.linalg.adjoint(L)  
    tr  = tf.linalg.trace(rho)
    return rho / tr[:, None, None]

def make_fidelity_loss(d):
    def fidelity_loss(alpha_true, alpha_pred):
        rho_t = tf_alpha_to_rho(alpha_true, d)
        rho_p = tf_alpha_to_rho(alpha_pred, d)

        # tiny regularizer to guard numeric issues
        I = tf.eye(d, dtype=tf.complex64)[None, :, :]
        rho_t = rho_t + 1e-8 * I
        rho_p = rho_p + 1e-8 * I

        sqrt_t = tf_sqrtm_psd(rho_t)
        inter  = sqrt_t @ (rho_p @ sqrt_t)
        s_mat  = tf_sqrtm_psd(inter)

        tr_s = tf.linalg.trace(s_mat)
        F = tf.abs(tr_s)**2
        return tf.reduce_mean(1.0 - F)
    return fidelity_loss

def make_hybrid_loss(d, lam=0.8):
    """
    Hybrid loss = lam * MSE + (1 - lam) * (1 - fidelity).
    """
    fid_loss_fn = make_fidelity_loss(d)

    def hybrid_loss(alpha_true, alpha_pred):
        # MSE on the Cholesky parameters
        mse = tf.reduce_mean(tf.square(alpha_true - alpha_pred))

        # fidelity loss already = mean(1 - F)
        phys = fid_loss_fn(alpha_true, alpha_pred)

        return lam * mse + (1.0 - lam) * phys

    return hybrid_loss

# %%
d = y_train.shape[1]

alphas_train = np.stack([rho_to_alpha(rho) for rho in y_train], axis=0)
N_alpha = alphas_train.shape[1]

model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(X_train.shape[1],)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(128, activation="relu"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(128, activation="relu"),
    tf.keras.layers.Dense(N_alpha),
])

model.compile(
    optimizer=tf.keras.optimizers.Adam(1e-3),
    loss=make_hybrid_loss(d),
)

# fit
history = model.fit(
    X_train, alphas_train,
    validation_split=0.3,
    epochs=50,
    batch_size=64,
)
# Out:
# Epoch 1/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.1682 - val_loss: 0.0307
# Epoch 2/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0373 - val_loss: 0.0281
# Epoch 3/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0322 - val_loss: 0.0268
# Epoch 4/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0307 - val_loss: 0.0261
# Epoch 5/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0301 - val_loss: 0.0259
# Epoch 6/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0294 - val_loss: 0.0254
# Epoch 7/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0289 - val_loss: 0.0252
# Epoch 8/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0289 - val_loss: 0.0253
# Epoch 9/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0286 - val_loss: 0.0250
# Epoch 10/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0286 - val_loss: 0.0251
# Epoch 11/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0284 - val_loss: 0.0246
# Epoch 12/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0284 - val_loss: 0.0250
# Epoch 13/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0281 - val_loss: 0.0248
# Epoch 14/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0280 - val_loss: 0.0248
# Epoch 15/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0282 - val_loss: 0.0247
# Epoch 16/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0280 - val_loss: 0.0246
# Epoch 17/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0279 - val_loss: 0.0246
# Epoch 18/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0278 - val_loss: 0.0247
# Epoch 19/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0277 - val_loss: 0.0246
# Epoch 20/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0278 - val_loss: 0.0248
# Epoch 21/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0275 - val_loss: 0.0245
# Epoch 22/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0275 - val_loss: 0.0248
# Epoch 23/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0273 - val_loss: 0.0249
# Epoch 24/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0276 - val_loss: 0.0247
# Epoch 25/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0276 - val_loss: 0.0245
# Epoch 26/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0273 - val_loss: 0.0245
# Epoch 27/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0274 - val_loss: 0.0247
# Epoch 28/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0275 - val_loss: 0.0245
# Epoch 29/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0273 - val_loss: 0.0245
# Epoch 30/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0274 - val_loss: 0.0246
# Epoch 31/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0274 - val_loss: 0.0246
# Epoch 32/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0272 - val_loss: 0.0246
# Epoch 33/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0272 - val_loss: 0.0246
# Epoch 34/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0271 - val_loss: 0.0243
# Epoch 35/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0273 - val_loss: 0.0246
# Epoch 36/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0273 - val_loss: 0.0247
# Epoch 37/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0272 - val_loss: 0.0244
# Epoch 38/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0273 - val_loss: 0.0244
# Epoch 39/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0272 - val_loss: 0.0245
# Epoch 40/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0270 - val_loss: 0.0244
# Epoch 41/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0269 - val_loss: 0.0245
# Epoch 42/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0271 - val_loss: 0.0244
# Epoch 43/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0272 - val_loss: 0.0245
# Epoch 44/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0270 - val_loss: 0.0247
# Epoch 45/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0271 - val_loss: 0.0245
# Epoch 46/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0271 - val_loss: 0.0243
# Epoch 47/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0269 - val_loss: 0.0246
# Epoch 48/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0271 - val_loss: 0.0243
# Epoch 49/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0269 - val_loss: 0.0244
# Epoch 50/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0269 - val_loss: 0.0242

# %%
def alpha_to_rho_batch(alpha):
    """Convert batch of alpha vectors to density matrices using Cholesky."""
    N = alpha.shape[0]
    rho = np.zeros((N, 4, 4), dtype=np.complex64)
    for i in range(N):
        a = alpha[i]
        L = np.zeros((4, 4), dtype=np.complex64)
        idx = 0
        for j in range(4):
            L[j, j] = a[idx]
            idx += 1
        for j in range(1, 4):
            for k in range(j):
                re = a[idx]
                im = a[idx + 1]
                L[j, k] = re + 1j * im
                idx += 2
        rho_i = L @ L.conj().T
        rho[i] = rho_i / np.trace(rho_i)
    return rho

def fidelity(rho1, rho2):
    """
    Uhlmann fidelity between two density matrices.
    inputs: the two density matrices to be compares
    """
    sqrt_rho1 = sqrtm(rho1)
    product = sqrt_rho1 @ rho2 @ sqrt_rho1
    sqrt_product = sqrtm(product)
    F = np.trace(sqrt_product)
    return np.real(F)**2


alpha_pred = model.predict(X_test)      
rho_pred = alpha_to_rho_batch(alpha_pred)  

# Compute fidelities
fidelities = np.array([
    fidelity(rho_pred[i], y_test[i])
    for i in range(len(rho_pred))
])

# Summary
mean_fid = np.mean(fidelities)
std_fid = np.std(fidelities)
print(f"Test Set Fidelity: {mean_fid:.4f} ± {std_fid:.4f}")
# Out:
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 308us/step
# Test Set Fidelity: 0.8455 ± 0.1187

# %%
model.save_weights("weights.weights.h5")

# %% [markdown]
# # High Shot No Noise Test

# %%
data = np.load('../datasets/2q_nonoise_10k_.npz')
X = data['counts']
y = data['states']

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7, random_state=2)

d = y_train.shape[1]

alphas_train = np.stack([rho_to_alpha(rho) for rho in y_train], axis=0)
N_alpha = alphas_train.shape[1]

model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(X_train.shape[1],)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(128, activation="relu"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(128, activation="relu"),
    tf.keras.layers.Dense(N_alpha),
])

model.compile(
    optimizer=tf.keras.optimizers.Adam(1e-3),
    loss=make_hybrid_loss(d),
)


history = model.fit(
    X_train, alphas_train,
    validation_split=0.3,
    epochs=50,
    batch_size=64,
)
# Out:
# Epoch 1/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.1711 - val_loss: 0.0142
# Epoch 2/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0238 - val_loss: 0.0095
# Epoch 3/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0170 - val_loss: 0.0075
# Epoch 4/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0145 - val_loss: 0.0066
# Epoch 5/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0135 - val_loss: 0.0058
# Epoch 6/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0128 - val_loss: 0.0057
# Epoch 7/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0123 - val_loss: 0.0054
# Epoch 8/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0119 - val_loss: 0.0051
# Epoch 9/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0115 - val_loss: 0.0051
# Epoch 10/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0113 - val_loss: 0.0049
# Epoch 11/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0112 - val_loss: 0.0048
# Epoch 12/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0110 - val_loss: 0.0045
# Epoch 13/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0108 - val_loss: 0.0044
# Epoch 14/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0106 - val_loss: 0.0043
# Epoch 15/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0105 - val_loss: 0.0047
# Epoch 16/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0105 - val_loss: 0.0046
# Epoch 17/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0103 - val_loss: 0.0048
# Epoch 18/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0102 - val_loss: 0.0044
# Epoch 19/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0101 - val_loss: 0.0041
# Epoch 20/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0101 - val_loss: 0.0044
# Epoch 21/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0101 - val_loss: 0.0043
# Epoch 22/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0101 - val_loss: 0.0044
# Epoch 23/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0100 - val_loss: 0.0046
# Epoch 24/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0100 - val_loss: 0.0044
# Epoch 25/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0098 - val_loss: 0.0043
# Epoch 26/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0098 - val_loss: 0.0044
# Epoch 27/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0098 - val_loss: 0.0043
# Epoch 28/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0097 - val_loss: 0.0044
# Epoch 29/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0097 - val_loss: 0.0041
# Epoch 30/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0096 - val_loss: 0.0042
# Epoch 31/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0096 - val_loss: 0.0041
# Epoch 32/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0042
# Epoch 33/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0096 - val_loss: 0.0042
# Epoch 34/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0044
# Epoch 35/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0043
# Epoch 36/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0095 - val_loss: 0.0039
# Epoch 37/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0041
# Epoch 38/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0094 - val_loss: 0.0041
# Epoch 39/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0094 - val_loss: 0.0039
# Epoch 40/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0040
# Epoch 41/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0041
# Epoch 42/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0042
# Epoch 43/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0093 - val_loss: 0.0042
# Epoch 44/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0043
# Epoch 45/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0094 - val_loss: 0.0046
# Epoch 46/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0093 - val_loss: 0.0041
# Epoch 47/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0041
# Epoch 48/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0092 - val_loss: 0.0045
# Epoch 49/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 0.0093 - val_loss: 0.0043
# Epoch 50/50
# 766/766 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.0093 - val_loss: 0.0041

# %%
alpha_pred = model.predict(X_test)      
rho_pred = alpha_to_rho_batch(alpha_pred)  

# Compute fidelities
fidelities = np.array([
    fidelity(rho_pred[i], y_test[i])
    for i in range(len(rho_pred))
])

# Summary
mean_fid = np.mean(fidelities)
std_fid = np.std(fidelities)
print(f"Test Set Fidelity: {mean_fid:.4f} ± {std_fid:.4f}")
# Out:
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 0s 369us/step
# Test Set Fidelity: 0.9799 ± 0.0178

# %% [markdown]
# python pure_mixed_build.py --n_qubits 2 --n_states 100000 --shots_per_basis 5000 --pure_fraction 0.5 --xi 0.0 --resample_per_state True --output 2q_5k_.npz
